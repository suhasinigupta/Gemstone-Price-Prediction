# %%
## importing basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"E:\Gemstone-Price-Prediction\notebook\data\gemstones.csv" )
df.head()
# Out:
#    Unnamed: 0  id  carat        cut color clarity  depth  table     x     y  \
# 0           0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33
# 1           1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12
# 2           2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73
# 3           3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41
# 4           4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61
#
#       z  price
# 0  4.55  13619
# 1  5.05  13387
# 2  3.50   2772
# 3  2.71    666
# 4  4.77  14453

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  193573 non-null  int64
#  1   id          193573 non-null  int64
#  2   carat       193573 non-null  float64
#  3   cut         193573 non-null  object
#  4   color       193573 non-null  object
#  5   clarity     193573 non-null  object
#  6   depth       193573 non-null  float64
#  7   table       193573 non-null  float64
#  8   x           193573 non-null  float64
#  9   y           193573 non-null  float64
#  10  z           193573 non-null  float64
#  11  price       193573 non-null  int64
# dtypes: float64(6), int64(3), object(3)
# memory usage: 17.7+ MB

# %%
cat_cols= df.select_dtypes(include=["object"]).columns
num_cols= df.select_dtypes(include=["int64","float64"]).drop(columns=["id","Unnamed: 0"], axis= 1).columns

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
for col in num_cols:
    sns.histplot(df[col], kde=True)
    plt.show()

# %%
sns.pairplot(df)

# %%
## correlation plot
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df['color'].value_counts()
# Out:
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: color, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: clarity, dtype: int64

# %%
df['cut'].value_counts()
# Out:
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: cut, dtype: int64
